# %%
dates = ["2013-10-23", "2013-11-04"]

# %%
import csv

# %%
f = open('30oysters.csv', 'rb')
reader = csv.reader(f)
rownum = 0
for row in reader:
    if rownum == 0:
        header = row
    else:
        #print row
        #print row[0].split()
        print map(float, row[0].split())
    rownum += 1
f.close()
# Out:
# [1.0, 12.92, 13.04, 5136699.0, 47907.0]
# [2.0, 11.4, 11.71, 4795151.0, 41458.0]
# [3.0, 17.42, 17.42, 6453115.0, 60891.0]
# [4.0, 6.79, 7.23, 2895239.0, 29949.0]
# [5.0, 9.62, 10.03, 3672746.0, 41616.0]
# [6.0, 15.5, 15.59, 5728880.0, 48070.0]
# [7.0, 9.66, 9.94, 3987582.0, 34717.0]
# [8.0, 7.02, 7.53, 2678423.0, 27230.0]
# [9.0, 12.56, 12.73, 5481545.0, 52712.0]
# [10.0, 12.49, 12.66, 5016762.0, 41500.0]
# [11.0, 10.12, 10.53, 3942783.0, 31216.0]
# [12.0, 10.64, 10.84, 4052638.0, 41852.0]
# [13.0, 12.99, 13.12, 5334558.0, 44608.0]
# [14.0, 8.09, 8.48, 3527926.0, 35343.0]
# [15.0, 14.09, 14.24, 5679636.0, 47481.0]
# [16.0, 10.73, 11.11, 4013992.0, 40976.0]
# [17.0, 15.17, 15.35, 5565995.0, 65361.0]
# [18.0, 15.5, 15.44, 6303198.0, 50910.0]
# [19.0, 5.22, 5.67, 1928109.0, 22895.0]
# [20.0, 7.75, 8.26, 3450164.0, 34804.0]
# [21.0, 10.71, 10.95, 4707532.0, 37156.0]
# [22.0, 7.91, 7.97, 3019077.0, 29070.0]
# [23.0, 6.93, 7.34, 2768160.0, 24590.0]
# ...
